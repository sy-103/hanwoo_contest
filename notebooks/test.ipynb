# %%
import pandas

test_df = pandas.read_csv("../data/test/test_hanwoo.csv")

print("\n=== test_df ===")
print(test_df.shape)
print(test_df.head(10))
print(test_df.columns.tolist())
# Out:
# === test_df ===
# (452497, 13)
#       sido sigungu eupmyeondong  stn  ABATT_DATE  JUDGE_DATE JUDGE_SEX  \
# 0  강원특별자치도     평창군          봉평면  525  2023-01-01  2023-01-02         암
# 1  강원특별자치도     평창군          봉평면  525  2023-01-01  2023-01-02         암
# 2  강원특별자치도     평창군          용평면  525  2023-01-01  2023-01-02         암
# 3  강원특별자치도     강릉시          옥계면  580  2023-01-01  2023-01-02         수
# 4  강원특별자치도     강릉시         주문진읍  523  2023-01-01  2023-01-02        거세
# 5  강원특별자치도     강릉시         주문진읍  523  2023-01-01  2023-01-02        거세
# 6  강원특별자치도     강릉시          옥계면  580  2023-01-01  2023-01-02         수
# 7  강원특별자치도     강릉시         주문진읍  523  2023-01-01  2023-01-02        거세
# 8  강원특별자치도     강릉시          옥계면  580  2023-01-01  2023-01-02         수
# 9  강원특별자치도     평창군          평창읍  526  2023-01-01  2023-01-02        거세
#
#    WEIGHT  AGE  BIRTH_YMD                                     CATTLE_NO  \
# 0     210   76   20160925  UgnVGyCTxzv22X5PJ3zCLLRi8g3YPA9Rg3HF3P9AjX8=
# ...
