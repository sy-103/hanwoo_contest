# %%
import pandas as pd
import numpy as np

df = pd.read_csv("../../data/processed/2_preprocess/step6_preprocess.csv", low_memory=False)

print("=== LAST_GRADE 분포 ===")
print(df["LAST_GRADE"].value_counts())
print(f"\n클래스 수: {df['LAST_GRADE'].nunique()}")
print(f"\n최다 클래스: {df['LAST_GRADE'].value_counts().index[0]} ({df['LAST_GRADE'].value_counts().iloc[0]:,}개, {df['LAST_GRADE'].value_counts().iloc[0]/len(df)*100:.2f}%)")
print(f"최소 클래스: {df['LAST_GRADE'].value_counts().index[-1]} ({df['LAST_GRADE'].value_counts().iloc[-1]:,}개, {df['LAST_GRADE'].value_counts().iloc[-1]/len(df)*100:.2f}%)")
print(f"불균형 비율: {df['LAST_GRADE'].value_counts().iloc[0]/df['LAST_GRADE'].value_counts().iloc[-1]:.1f}배")
# Out:
# === LAST_GRADE 분포 ===
# LAST_GRADE
# 1++B    319588
# 1+B     311222
# 1B      299290
# 1++A    207026
# 2B      195866
# 1A      168174
# 1+A     167246
# 1+C     130094
# 1++C    128997
# 2A      127410
# 1C      116976
# 3B       97576
# 2C       62938
# 3A       47214
# 3C       23542
# 등외        5540
# Name: count, dtype: int64
#
# 클래스 수: 16
#
# 최다 클래스: 1++B (319,588개, 13.27%)
# 최소 클래스: 등외 (5,540개, 0.23%)
# 불균형 비율: 57.7배
